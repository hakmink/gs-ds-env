# %%
import os

import boto3
import sagemaker
from sagemaker.estimator import Estimator


os.environ["AWS_PROFILE"] = "155954279556_kunops"
# ============================================================
# 기본 설정
# ============================================================
session    = boto3.Session(region_name="us-west-1")
sm_session = sagemaker.Session(boto_session=session)

REGION     = session.region_name
ACCOUNT_ID = boto3.client("sts").get_caller_identity()["Account"]

# ============================================================
# 경로 설정
# ============================================================
IMAGE_URI         = "155954279556.dkr.ecr.us-west-1.amazonaws.com/gs-automl-base-containers/boilerplate312_sm:kunops-v1.2"
SAGEMAKER_ROLE    = "arn:aws:iam::155954279556:role/service-role/AmazonSageMaker-ExecutionRole-20260211T204344"

CONF_S3_PATH      = "s3://gs-retail-awesome-conf-us-west-1/dev/kunops/titanic-survival-prediction/kunops-v1/"
WORK_DIR          = "/opt/ml/code"
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials

# %%
# ============================================================
# Estimator 설정
# ============================================================
estimator = Estimator(
    base_job_name  = "boilerplate312-sm-sample",
    image_uri      = IMAGE_URI,
    entry_point    = "run_pm.py",
    role           = SAGEMAKER_ROLE,
    instance_type  = "ml.m5.xlarge",
    instance_count = 1,
	source_dir=".",
    sagemaker_session = sm_session,
    hyperparameters = {
        "conf-s3-path"  : CONF_S3_PATH,
        "work-dir"      : WORK_DIR,
    },
)

# ============================================================
# 학습 실행
# ============================================================
estimator.fit(wait=True, logs="All")
# Out:
# INFO:sagemaker:Creating training-job with name: boilerplate312-sm-sample-2026-03-17-07-12-17-623
# 2026-03-17 07:12:24 Starting - Starting the training job...
# 2026-03-17 07:12:58 Downloading - Downloading input data...
# 2026-03-17 07:13:13 Downloading - Downloading the training image...
# 2026-03-17 07:14:06 Training - Training image download completed. Training in progress.
# 2026-03-17 07:14:06 Uploading - Uploading generated training model
# 2026-03-17 07:14:06 Completed - Training job completed
# 2026-03-17 07:13:48,760 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-03-17 07:13:48,761 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-03-17 07:13:48,774 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-03-17 07:13:48,775 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-03-17 07:13:48,790 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-03-17 07:13:48,791 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-03-17 07:13:48,805 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.m5.xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "conf-s3-path": "s3://gs-retail-awesome-conf-us-west-1/dev/kunops/titanic-survival-prediction/kunops-v1/",
#         "work-dir": "/opt/ml/code"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.m5.xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": false,
#     "job_name": "boilerplate312-sm-sample-2026-03-17-07-12-17-623",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-1-155954279556/boilerplate312-sm-sample-2026-03-17-07-12-17-623/source/sourcedir.tar.gz",
#     "module_name": "run_pm",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0",
#         "topology": null
#     },
#     "user_entry_point": "run_pm.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"conf-s3-path":"s3://gs-retail-awesome-conf-us-west-1/dev/kunops/titanic-survival-prediction/kunops-v1/","work-dir":"/opt/ml/code"}
# SM_USER_ENTRY_POINT=run_pm.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0","topology":null}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.m5.xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=run_pm
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-1-155954279556/boilerplate312-sm-sample-2026-03-17-07-12-17-623/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.m5.xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":null,"hosts":["algo-1"],"hyperparameters":{"conf-s3-path":"s3://gs-retail-awesome-conf-us-west-1/dev/kunops/titanic-survival-prediction/kunops-v1/","work-dir":"/opt/ml/code"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"boilerplate312-sm-sample-2026-03-17-07-12-17-623","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-1-155954279556/boilerplate312-sm-sample-2026-03-17-07-12-17-623/source/sourcedir.tar.gz","module_name":"run_pm","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.xlarge"}],"network_interface_name":"eth0","topology":null},"user_entry_point":"run_pm.py"}
# SM_USER_ARGS=["--conf-s3-path","s3://gs-retail-awesome-conf-us-west-1/dev/kunops/titanic-survival-prediction/kunops-v1/","--work-dir","/opt/ml/code"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_CONF-S3-PATH=s3://gs-retail-awesome-conf-us-west-1/dev/kunops/titanic-survival-prediction/kunops-v1/
# SM_HP_WORK-DIR=/opt/ml/code
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python312.zip:/usr/local/lib/python3.12:/usr/local/lib/python3.12/lib-dynload:/usr/local/lib/python3.12/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.12 run_pm.py --conf-s3-path s3://gs-retail-awesome-conf-us-west-1/dev/kunops/titanic-survival-prediction/kunops-v1/ --work-dir /opt/ml/code
# 2026-03-17 07:13:48,805 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2026-03-17 07:13:48,806 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# AWS Account ID: 155954279556
# AWS Region: ap-northeast-2
# args ++++
# {   'dataset_profile_table_name': '',
#     'dataset_table_name': '',
#     'dryrun': 'false',
#     'experiment_hashkey': '',
#     'experiment_result_table_name': '',
#     'experiment_table_name': '',
#     'job_type': '',
#     'model_repo_table_name': '',
#     'profile_hashkey': '',
#     'project_hashkey': '',
#     'task_token': '',
#     'username': ''}
# unknown ++++
# [   '--conf-s3-path',
#     's3://gs-retail-awesome-conf-us-west-1/dev/kunops/titanic-survival-prediction/kunops-v1/',
#     '--work-dir', '/opt/ml/code']
# Namespace(project_hashkey='', experiment_hashkey='', profile_hashkey='', experiment_table_name='', experiment_result_table_name='', dataset_table_name='', dataset_profile_table_name='', model_repo_table_name='', username='', task_token='', dryrun='false', job_type='')
# 2026-03-17 07:13:50,138 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 69
# Billable seconds: 69
