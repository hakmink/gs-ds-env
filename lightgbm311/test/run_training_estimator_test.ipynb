# %%
# %pip freeze | grep sagemaker
# Out:
# sagemaker==2.235.2
# sagemaker-core==1.0.77
# sagemaker-experiments==0.1.45
# sagemaker_training==4.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sagemaker
from sagemaker.estimator import Estimator
from sagemaker import get_execution_role
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
role = get_execution_role()
sess = sagemaker.Session()

# %% [markdown]
# ## Model Train job 실행

# %%
# ============================================
# Estimator 생성
# ============================================
estimator = Estimator(
    # 앞서 빌드한 SageMaker 이미지 사용
    image_uri='155954279556.dkr.ecr.us-east-1.amazonaws.com/gs-automl-base-containers/lightgbm311_sm:1.0',
    role=role,
    instance_count=1,
    instance_type='ml.m5.large',  # 또는 ml.m5.xlarge

    # 하이퍼파라미터 (선택적)
    hyperparameters={
        "table_name": "automl-lightgbm-experiment",
        "project_hashkey": "2ee07a49",
        "experiment_hashkey": "1cbd8309",
        "dataset_table_name": "automl-dataset",
        "username": "hjsong@gsretail.com", 
        "job_type": "training",
        "task_token": "1234",
    },

    base_job_name='train-titanic-lightgbm',
    sagemaker_session=sess,

    # 태그
    tags=[
        {'Key': 'Environment', 'Value': 'dev'},
        {'Key': 'Project', 'Value': 'automl'},
        {'Key': 'Owner', 'Value': 'hjsong'},
        {'Key': 'CostCenter', 'Value': 'gs-retail'}
    ],

    # 출력 경로
    output_path=f's3://retail-mlops-edu-2026/edu-2w/hjsong/output',
)

# %%
# ============================================
# 학습 데이터 준비
# ============================================
# 학습 데이터를 S3에 업로드
train_s3_path = sess.upload_data(
    path='train.csv',
    bucket='retail-mlops-edu-2026',
    key_prefix='edu-2w/hjsong/input'
)

print(f"Training data uploaded to: {train_s3_path}")
# Out:
# Training data uploaded to: s3://retail-mlops-edu-2026/edu-2w/hjsong/input/train.csv

# %%
# ============================================
# Training Job 실행
# ============================================
try:
    estimator.fit({
        'training': train_s3_path
    })

    print("=" * 60)
    print("✅ Training Job 완료!")
    print(f"   Job Name: {estimator.latest_training_job.name}")
    print(f"   Model Artifact: {estimator.model_data}")
    print("=" * 60)

except Exception as e:
    print(f"❌ Training Job 실패: {e}")
# Out:
# INFO:sagemaker:Creating training-job with name: train-titanic-lightgbm-2026-02-26-14-28-23-007
# 2026-02-26 14:28:24 Starting - Starting the training job...
# 2026-02-26 14:28:39 Starting - Preparing the instances for training...
# 2026-02-26 14:29:03 Downloading - Downloading input data...
# 2026-02-26 14:29:33 Downloading - Downloading the training image.....2026-02-26 14:30:32,494 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-02-26 14:30:32,495 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_table_name value automl-dataset to Json.
# Returning the value itself
# 2026-02-26 14:30:32,495 sagemaker-training-toolkit INFO     Failed to parse hyperparameter experiment_hashkey value 1cbd8309 to Json.
# Returning the value itself
# 2026-02-26 14:30:32,495 sagemaker-training-toolkit INFO     Failed to parse hyperparameter job_type value training to Json.
# Returning the value itself
# 2026-02-26 14:30:32,495 sagemaker-training-toolkit INFO     Failed to parse hyperparameter project_hashkey value 2ee07a49 to Json.
# Returning the value itself
# 2026-02-26 14:30:32,495 sagemaker-training-toolkit INFO     Failed to parse hyperparameter table_name value automl-lightgbm-experiment to Json.
# Returning the value itself
# 2026-02-26 14:30:32,495 sagemaker-training-toolkit INFO     Failed to parse hyperparameter username value hjsong@gsretail.com to Json.
# Returning the value itself
# 2026-02-26 14:30:32,496 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-02-26 14:30:32,512 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-02-26 14:30:32,512 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_table_name value automl-dataset to Json.
# Returning the value itself
# 2026-02-26 14:30:32,512 sagemaker-training-toolkit INFO     Failed to parse hyperparameter experiment_hashkey value 1cbd8309 to Json.
# Returning the value itself
# 2026-02-26 14:30:32,512 sagemaker-training-toolkit INFO     Failed to parse hyperparameter job_type value training to Json.
# Returning the value itself
# 2026-02-26 14:30:32,512 sagemaker-training-toolkit INFO     Failed to parse hyperparameter project_hashkey value 2ee07a49 to Json.
# Returning the value itself
# 2026-02-26 14:30:32,512 sagemaker-training-toolkit INFO     Failed to parse hyperparameter table_name value automl-lightgbm-experiment to Json.
# Returning the value itself
# 2026-02-26 14:30:32,513 sagemaker-training-toolkit INFO     Failed to parse hyperparameter username value hjsong@gsretail.com to Json.
# Returning the value itself
# 2026-02-26 14:30:32,513 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-02-26 14:30:32,524 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-02-26 14:30:32,524 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_table_name value automl-dataset to Json.
# Returning the value itself
# 2026-02-26 14:30:32,524 sagemaker-training-toolkit INFO     Failed to parse hyperparameter experiment_hashkey value 1cbd8309 to Json.
# Returning the value itself
# 2026-02-26 14:30:32,525 sagemaker-training-toolkit INFO     Failed to parse hyperparameter job_type value training to Json.
# Returning the value itself
# 2026-02-26 14:30:32,525 sagemaker-training-toolkit INFO     Failed to parse hyperparameter project_hashkey value 2ee07a49 to Json.
# Returning the value itself
# 2026-02-26 14:30:32,525 sagemaker-training-toolkit INFO     Failed to parse hyperparameter table_name value automl-lightgbm-experiment to Json.
# Returning the value itself
# 2026-02-26 14:30:32,525 sagemaker-training-toolkit INFO     Failed to parse hyperparameter username value hjsong@gsretail.com to Json.
# Returning the value itself
# 2026-02-26 14:30:32,526 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-02-26 14:30:32,538 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.m5.large",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "dataset_table_name": "automl-dataset",
#         "experiment_hashkey": "1cbd8309",
#         "job_type": "training",
#         "project_hashkey": "2ee07a49",
#         "table_name": "automl-lightgbm-experiment",
#         "task_token": 1234,
#         "username": "hjsong@gsretail.com"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.m5.large",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": false,
#     "job_name": "train-titanic-lightgbm-2026-02-26-14-28-23-007",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "run_pm",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0",
#         "topology": null
#     },
#     "user_entry_point": "run_pm.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"dataset_table_name":"automl-dataset","experiment_hashkey":"1cbd8309","job_type":"training","project_hashkey":"2ee07a49","table_name":"automl-lightgbm-experiment","task_token":1234,"username":"hjsong@gsretail.com"}
# SM_USER_ENTRY_POINT=run_pm.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0","topology":null}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.m5.large
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=run_pm
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.m5.large","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":null,"hosts":["algo-1"],"hyperparameters":{"dataset_table_name":"automl-dataset","experiment_hashkey":"1cbd8309","job_type":"training","project_hashkey":"2ee07a49","table_name":"automl-lightgbm-experiment","task_token":1234,"username":"hjsong@gsretail.com"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"train-titanic-lightgbm-2026-02-26-14-28-23-007","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"run_pm","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0","topology":null},"user_entry_point":"run_pm.py"}
# SM_USER_ARGS=["--dataset_table_name","automl-dataset","--experiment_hashkey","1cbd8309","--job_type","training","--project_hashkey","2ee07a49","--table_name","automl-lightgbm-experiment","--task_token","1234","--username","hjsong@gsretail.com"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_DATASET_TABLE_NAME=automl-dataset
# SM_HP_EXPERIMENT_HASHKEY=1cbd8309
# SM_HP_JOB_TYPE=training
# SM_HP_PROJECT_HASHKEY=2ee07a49
# SM_HP_TABLE_NAME=automl-lightgbm-experiment
# SM_HP_TASK_TOKEN=1234
# SM_HP_USERNAME=hjsong@gsretail.com
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python311.zip:/usr/local/lib/python3.11:/usr/local/lib/python3.11/lib-dynload:/usr/local/lib/python3.11/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.11 run_pm.py --dataset_table_name automl-dataset --experiment_hashkey 1cbd8309 --job_type training --project_hashkey 2ee07a49 --table_name automl-lightgbm-experiment --task_token 1234 --username hjsong@gsretail.com
# 2026-02-26 14:30:32,540 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2026-02-26 14:30:32,540 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# AWS Account ID: 155954279556
# AWS Region: ap-northeast-2
# #015Executing:   0%|          | 0/16 [00:00<?, ?cell/s]#015Executing:   6%|▋         | 1/16 [00:01<00:22,  1.48s/cell]#015Executing:  50%|█████     | 8/16 [00:01<00:01,  6.55cell/s]#015Executing:  69%|██████▉   | 11/16 [00:02<00:01,  4.45cell/s]#015Executing:  88%|████████▊ | 14/16 [00:02<00:00,  5.62cell/s]#015Executing: 100%|██████████| 16/16 [00:03<00:00,  6.17cell/s]#015Executing: 100%|██████████| 16/16 [00:03<00:00,  4.34cell/s]
# Uploaded to: s3://retail-mlops-edu-2026/edu-2w/hjsong/output/train_titanic_lightgbm_output.ipynb
# 2026-02-26 14:30:37,550 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2026-02-26 14:30:57 Training - Training image download completed. Training in progress.
# 2026-02-26 14:30:57 Uploading - Uploading generated training model
# 2026-02-26 14:30:57 Completed - Training job completed
# Training seconds: 114
# Billable seconds: 114
# ============================================================
# ✅ Training Job 완료!
#    Job Name: train-titanic-lightgbm-2026-02-26-14-28-23-007
#    Model Artifact: s3://retail-mlops-edu-2026/edu-2w/hjsong/output/train-titanic-lightgbm-2026-02-26-14-28-23-007/output/model.tar.gz
# ============================================================

# %% [markdown]
# ## 결과 확인

# %%
# ============================================================
# Step 3: 결과 노트북 다운로드 및 확인
# ============================================================

import boto3
import os
import pandas as pd

s3 = boto3.client('s3')

# ============================================
# 실행된 노트북 다운로드
# ============================================
bucket = 'retail-mlops-edu-2026'
key = 'edu-2w/hjsong/output/train_titanic_lightgbm_output.ipynb'
local_path = 'titanic_output.ipynb'

s3.download_file(bucket, key, local_path)

print(f"✅ 결과 노트북 다운로드 완료: {local_path}")
print(f"   Jupyter에서 열어서 확인하세요!")

# ============================================
# 모델 다운로드
# ============================================
print(estimator.latest_training_job.name)
model_key = f"edu-2w/hjsong/output/{estimator.latest_training_job.name}/output/model.tar.gz"
model_local = 'model.tar.gz'
s3.download_file(bucket, model_key, model_local)

# 압축 해제
import tarfile
with tarfile.open(model_local, 'r:gz') as tar:
    tar.extractall('model')

print(f"✅ 모델 다운로드 완료: ./model/")

# ============================================
# 모델 로드 및 테스트
# ============================================
import joblib

model = joblib.load('model/titanic_model.joblib')

# 테스트 데이터로 예측
val_key = "edu-2w/hjsong/data/val/validation.csv"
val_local = "test.csv"
s3.download_file(bucket, val_key, val_local)
test_df = pd.read_csv('test.csv')
# ... 전처리
predictions = model.predict(test_df)

print(f"✅ 예측 완료: {len(predictions)} samples")
# Out:
# ✅ 결과 노트북 다운로드 완료: titanic_output.ipynb
#    Jupyter에서 열어서 확인하세요!
# train-titanic-lightgbm-2026-02-26-14-28-23-007
# ✅ 모델 다운로드 완료: ./model/
# [LightGBM] [Fatal] The number of features in data (12) is not the same as it was in training data (11).
# You can set ``predict_disable_shape_check=true`` to discard this error, but please be aware what you are doing.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:51                                                                                   │
# │                                                                                                  │
# │   48 s3.download_file(bucket, val_key, val_local)                                                │
# │   49 test_df = pd.read_csv('test.csv')                                                           │
# │   50 # ... 전처리                                                                                │
# │ ❱ 51 predictions = model.predict(test_df)                                                        │
# │   52                                                                                             │
# │   53 print(f"✅ 예측 완료: {len(predictions)} samples")                                          │
# │   54                                                                                             │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/.myenv/miniconda/envs/lightgbm311/lib/python3.11/site-packages/lightgbm │
# │ /sklearn.py:1597 in predict                                                                      │
# │                                                                                                  │
# │   1594 │   │   **kwargs: Any,                                                                    │
# │   1595 │   ):                                                                                    │
# │   1596 │   │   """Docstring is inherited from the LGBMModel."""                                  │
# │ ❱ 1597 │   │   result = self.predict_proba(                                                      │
# │   1598 │   │   │   X=X,                                                                          │
# │   1599 │   │   │   raw_score=raw_score,                                                          │
# │   1600 │   │   │   start_iteration=start_iteration,                                              │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/.myenv/miniconda/envs/lightgbm311/lib/python3.11/site-packages/lightgbm │
# │ /sklearn.py:1627 in predict_proba                                                                │
# │                                                                                                  │
# │   1624 │   │   **kwargs: Any,                                                                    │
# │   1625 │   ):                                                                                    │
# │   1626 │   │   """Docstring is set after definition, using a template."""                        │
# │ ❱ 1627 │   │   result = super().predict(                                                         │
# │   1628 │   │   │   X=X,                                                                          │
# │   1629 │   │   │   raw_score=raw_score,                                                          │
# │   1630 │   │   │   start_iteration=start_iteration,                                              │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/.myenv/miniconda/envs/lightgbm311/lib/python3.11/site-packages/lightgbm │
# │ /sklearn.py:1144 in predict                                                                      │
# │                                                                                                  │
# │   1141 │   │   predict_params = _choose_param_value("num_threads", predict_params, self.n_jobs)  │
# │   1142 │   │   predict_params["num_threads"] = self._process_n_jobs(predict_params["num_threads  │
# │   1143 │   │                                                                                     │
# │ ❱ 1144 │   │   return self._Booster.predict(  # type: ignore[union-attr]                         │
# │   1145 │   │   │   X,                                                                            │
# │   1146 │   │   │   raw_score=raw_score,                                                          │
# │   1147 │   │   │   start_iteration=start_iteration,                                              │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/.myenv/miniconda/envs/lightgbm311/lib/python3.11/site-packages/lightgbm │
# │ /basic.py:4767 in predict                                                                        │
# │                                                                                                  │
# │   4764 │   │   │   │   num_iteration = self.best_iteration                                       │
# │   4765 │   │   │   else:                                                                         │
# │   4766 │   │   │   │   num_iteration = -1                                                        │
# │ ❱ 4767 │   │   return predictor.predict(                                                         │
# │   4768 │   │   │   data=data,                                                                    │
# │   4769 │   │   │   start_iteration=start_iteration,                                              │
# │   4770 │   │   │   num_iteration=num_iteration,                                                  │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/.myenv/miniconda/envs/lightgbm311/lib/python3.11/site-packages/lightgbm │
# │ /basic.py:1204 in predict                                                                        │
# │                                                                                                  │
# │   1201 │   │   │   │   predict_type=predict_type,                                                │
# │   1202 │   │   │   )                                                                             │
# │   1203 │   │   elif isinstance(data, np.ndarray):                                                │
# │ ❱ 1204 │   │   │   preds, nrow = self.__pred_for_np2d(                                           │
# │   1205 │   │   │   │   mat=data,                                                                 │
# │   1206 │   │   │   │   start_iteration=start_iteration,                                          │
# │   1207 │   │   │   │   num_iteration=num_iteration,                                              │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/.myenv/miniconda/envs/lightgbm311/lib/python3.11/site-packages/lightgbm │
# │ /basic.py:1361 in __pred_for_np2d                                                                │
# │                                                                                                  │
# │   1358 │   │   │   │   )                                                                         │
# │   1359 │   │   │   return preds, nrow                                                            │
# │   1360 │   │   else:                                                                             │
# │ ❱ 1361 │   │   │   return self.__inner_predict_np2d(                                             │
# │   1362 │   │   │   │   mat=mat,                                                                  │
# │   1363 │   │   │   │   start_iteration=start_iteration,                                          │
# │   1364 │   │   │   │   num_iteration=num_iteration,                                              │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/.myenv/miniconda/envs/lightgbm311/lib/python3.11/site-packages/lightgbm │
# │ /basic.py:1307 in __inner_predict_np2d                                                           │
# │                                                                                                  │
# │   1304 │   │   elif len(preds.shape) != 1 or len(preds) != n_preds:                              │
# │   1305 │   │   │   raise ValueError("Wrong length of pre-allocated predict array")               │
# │   1306 │   │   out_num_preds = ctypes.c_int64(0)                                                 │
# │ ❱ 1307 │   │   _safe_call(                                                                       │
# │   1308 │   │   │   _LIB.LGBM_BoosterPredictForMat(                                               │
# │   1309 │   │   │   │   self._handle,                                                             │
# │   1310 │   │   │   │   ptr_data,                                                                 │
# │                                                                                                  │
# │ /home/ec2-user/SageMaker/.myenv/miniconda/envs/lightgbm311/lib/python3.11/site-packages/lightgbm │
# │ /basic.py:313 in _safe_call                                                                      │
# │                                                                                                  │
# │    310 │   │   The return value from C API calls.                                                │
# │    311 │   """                                                                                   │
# │    312 │   if ret != 0:                                                                          │
# │ ❱  313 │   │   raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))                     │
# │    314                                                                                           │
# │    315                                                                                           │
# │    316 def _is_numeric(obj: Any) -> bool:                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# LightGBMError: The number of features in data (12) is not the same as it was in training data (11).
# You can set ``predict_disable_shape_check=true`` to discard this error, but please be aware what you are doing.
