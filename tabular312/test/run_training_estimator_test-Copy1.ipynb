# %%
# %pip freeze | grep sagemaker
# Out:
# sagemaker==2.235.2
# sagemaker-core==1.0.76
# sagemaker-experiments==0.1.45
# sagemaker_training==4.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sagemaker.estimator import Estimator
from sagemaker.session import Session
from sagemaker import get_execution_role
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
role = get_execution_role()
sess = Session()

# %%
estimator = Estimator(
    image_uri='155954279556.dkr.ecr.us-east-1.amazonaws.com/gs-automl-base-containers/tabular312_sm:1.0',
    role=role,
    instance_count=1,
    instance_type='ml.m5.large',
    hyperparameters={
        "table_name": "automl-classification-experiment",
        "project_hashkey": "2ee07a49",
        "experiment_hashkey": "1cbd8309",
        "dataset_table_name": "automl-dataset",
        "dataset_profile_table_name": "automl-dataset-profile-experiment-result",
        "model_repo_table_name": "automl-model-repo",
        "model_experiment_result_table_name": "automl-classification-experiment",
        "username": "sean@gs.co.kr",
        "job_type": "training",
        "task_token": "1234",
    },
    base_job_name='custom-training',
    sagemaker_session=sess,
    # 태그 설정 (SCP 요구사항 충족)
    tags=[
        {'Key': 'Environment', 'Value': 'dev'},
        {'Key': 'Project', 'Value': 'automl'},
        {'Key': 'Owner', 'Value': 'sean'},
        {'Key': 'CostCenter', 'Value': 'gs-retail'}
    ],
    # 기존 버킷 사용 (버킷 생성 방지)
    output_path=f's3://retail-mlops-edu-202602/output',
)

try:
    estimator.fit()
except ValueError as e:
    print(e)
# Out:
# INFO:sagemaker:Creating training-job with name: custom-training-2026-02-10-15-45-43-653
# 2026-02-10 15:45:45 Starting - Starting the training job...
# 2026-02-10 15:46:01 Starting - Preparing the instances for training...
# 2026-02-10 15:46:30 Downloading - Downloading input data...
# 2026-02-10 15:46:55 Downloading - Downloading the training image.....2026-02-10 15:47:58,290 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-02-10 15:47:58,290 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_profile_table_name value automl-dataset-profile-experiment-result to Json.
# Returning the value itself
# 2026-02-10 15:47:58,291 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_table_name value automl-dataset to Json.
# Returning the value itself
# 2026-02-10 15:47:58,291 sagemaker-training-toolkit INFO     Failed to parse hyperparameter experiment_hashkey value 1cbd8309 to Json.
# Returning the value itself
# 2026-02-10 15:47:58,291 sagemaker-training-toolkit INFO     Failed to parse hyperparameter job_type value training to Json.
# Returning the value itself
# 2026-02-10 15:47:58,291 sagemaker-training-toolkit INFO     Failed to parse hyperparameter model_experiment_result_table_name value automl-classification-experiment to Json.
# Returning the value itself
# 2026-02-10 15:47:58,291 sagemaker-training-toolkit INFO     Failed to parse hyperparameter model_repo_table_name value automl-model-repo to Json.
# Returning the value itself
# 2026-02-10 15:47:58,291 sagemaker-training-toolkit INFO     Failed to parse hyperparameter project_hashkey value 2ee07a49 to Json.
# Returning the value itself
# 2026-02-10 15:47:58,291 sagemaker-training-toolkit INFO     Failed to parse hyperparameter table_name value automl-classification-experiment to Json.
# Returning the value itself
# 2026-02-10 15:47:58,292 sagemaker-training-toolkit INFO     Failed to parse hyperparameter username value sean@gs.co.kr to Json.
# Returning the value itself
# 2026-02-10 15:47:58,292 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-02-10 15:47:58,343 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-02-10 15:47:58,344 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_profile_table_name value automl-dataset-profile-experiment-result to Json.
# Returning the value itself
# 2026-02-10 15:47:58,344 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_table_name value automl-dataset to Json.
# Returning the value itself
# 2026-02-10 15:47:58,344 sagemaker-training-toolkit INFO     Failed to parse hyperparameter experiment_hashkey value 1cbd8309 to Json.
# Returning the value itself
# 2026-02-10 15:47:58,344 sagemaker-training-toolkit INFO     Failed to parse hyperparameter job_type value training to Json.
# Returning the value itself
# 2026-02-10 15:47:58,344 sagemaker-training-toolkit INFO     Failed to parse hyperparameter model_experiment_result_table_name value automl-classification-experiment to Json.
# Returning the value itself
# 2026-02-10 15:47:58,344 sagemaker-training-toolkit INFO     Failed to parse hyperparameter model_repo_table_name value automl-model-repo to Json.
# Returning the value itself
# 2026-02-10 15:47:58,344 sagemaker-training-toolkit INFO     Failed to parse hyperparameter project_hashkey value 2ee07a49 to Json.
# Returning the value itself
# 2026-02-10 15:47:58,344 sagemaker-training-toolkit INFO     Failed to parse hyperparameter table_name value automl-classification-experiment to Json.
# Returning the value itself
# 2026-02-10 15:47:58,344 sagemaker-training-toolkit INFO     Failed to parse hyperparameter username value sean@gs.co.kr to Json.
# Returning the value itself
# 2026-02-10 15:47:58,345 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-02-10 15:47:58,356 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2026-02-10 15:47:58,356 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_profile_table_name value automl-dataset-profile-experiment-result to Json.
# Returning the value itself
# 2026-02-10 15:47:58,356 sagemaker-training-toolkit INFO     Failed to parse hyperparameter dataset_table_name value automl-dataset to Json.
# Returning the value itself
# 2026-02-10 15:47:58,356 sagemaker-training-toolkit INFO     Failed to parse hyperparameter experiment_hashkey value 1cbd8309 to Json.
# Returning the value itself
# 2026-02-10 15:47:58,357 sagemaker-training-toolkit INFO     Failed to parse hyperparameter job_type value training to Json.
# Returning the value itself
# 2026-02-10 15:47:58,357 sagemaker-training-toolkit INFO     Failed to parse hyperparameter model_experiment_result_table_name value automl-classification-experiment to Json.
# Returning the value itself
# 2026-02-10 15:47:58,357 sagemaker-training-toolkit INFO     Failed to parse hyperparameter model_repo_table_name value automl-model-repo to Json.
# Returning the value itself
# 2026-02-10 15:47:58,357 sagemaker-training-toolkit INFO     Failed to parse hyperparameter project_hashkey value 2ee07a49 to Json.
# Returning the value itself
# 2026-02-10 15:47:58,357 sagemaker-training-toolkit INFO     Failed to parse hyperparameter table_name value automl-classification-experiment to Json.
# Returning the value itself
# 2026-02-10 15:47:58,357 sagemaker-training-toolkit INFO     Failed to parse hyperparameter username value sean@gs.co.kr to Json.
# Returning the value itself
# 2026-02-10 15:47:58,358 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2026-02-10 15:47:58,369 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.m5.large",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": null,
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "dataset_profile_table_name": "automl-dataset-profile-experiment-result",
#         "dataset_table_name": "automl-dataset",
#         "experiment_hashkey": "1cbd8309",
#         "job_type": "training",
#         "model_experiment_result_table_name": "automl-classification-experiment",
#         "model_repo_table_name": "automl-model-repo",
#         "project_hashkey": "2ee07a49",
#         "table_name": "automl-classification-experiment",
#         "task_token": 1234,
#         "username": "sean@gs.co.kr"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.m5.large",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": false,
#     "job_name": "custom-training-2026-02-10-15-45-43-653",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "run_pm",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0",
#         "topology": null
#     },
#     "user_entry_point": "run_pm.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"dataset_profile_table_name":"automl-dataset-profile-experiment-result","dataset_table_name":"automl-dataset","experiment_hashkey":"1cbd8309","job_type":"training","model_experiment_result_table_name":"automl-classification-experiment","model_repo_table_name":"automl-model-repo","project_hashkey":"2ee07a49","table_name":"automl-classification-experiment","task_token":1234,"username":"sean@gs.co.kr"}
# SM_USER_ENTRY_POINT=run_pm.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0","topology":null}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.m5.large
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=run_pm
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.m5.large","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":null,"hosts":["algo-1"],"hyperparameters":{"dataset_profile_table_name":"automl-dataset-profile-experiment-result","dataset_table_name":"automl-dataset","experiment_hashkey":"1cbd8309","job_type":"training","model_experiment_result_table_name":"automl-classification-experiment","model_repo_table_name":"automl-model-repo","project_hashkey":"2ee07a49","table_name":"automl-classification-experiment","task_token":1234,"username":"sean@gs.co.kr"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"custom-training-2026-02-10-15-45-43-653","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"run_pm","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0","topology":null},"user_entry_point":"run_pm.py"}
# SM_USER_ARGS=["--dataset_profile_table_name","automl-dataset-profile-experiment-result","--dataset_table_name","automl-dataset","--experiment_hashkey","1cbd8309","--job_type","training","--model_experiment_result_table_name","automl-classification-experiment","--model_repo_table_name","automl-model-repo","--project_hashkey","2ee07a49","--table_name","automl-classification-experiment","--task_token","1234","--username","sean@gs.co.kr"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_DATASET_PROFILE_TABLE_NAME=automl-dataset-profile-experiment-result
# SM_HP_DATASET_TABLE_NAME=automl-dataset
# SM_HP_EXPERIMENT_HASHKEY=1cbd8309
# SM_HP_JOB_TYPE=training
# SM_HP_MODEL_EXPERIMENT_RESULT_TABLE_NAME=automl-classification-experiment
# SM_HP_MODEL_REPO_TABLE_NAME=automl-model-repo
# SM_HP_PROJECT_HASHKEY=2ee07a49
# SM_HP_TABLE_NAME=automl-classification-experiment
# SM_HP_TASK_TOKEN=1234
# SM_HP_USERNAME=sean@gs.co.kr
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python312.zip:/usr/local/lib/python3.12:/usr/local/lib/python3.12/lib-dynload:/usr/local/lib/python3.12/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.12 run_pm.py --dataset_profile_table_name automl-dataset-profile-experiment-result --dataset_table_name automl-dataset --experiment_hashkey 1cbd8309 --job_type training --model_experiment_result_table_name automl-classification-experiment --model_repo_table_name automl-model-repo --project_hashkey 2ee07a49 --table_name automl-classification-experiment --task_token 1234 --username sean@gs.co.kr
# 2026-02-10 15:47:58,373 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2026-02-10 15:47:58,373 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# AWS Account ID: 155954279556
# AWS Region: ap-northeast-2
#
# 2026-02-10 15:47:55 Training - Training image download completed. Training in progress.#015Executing:   0%|          | 0/201 [00:00<?, ?cell/s]#015Executing:   0%|          | 1/201 [00:01<03:56,  1.18s/cell]#015Executing:   2%|▏         | 4/201 [00:01<00:50,  3.89cell/s]#015Executing:   3%|▎         | 7/201 [00:01<00:29,  6.59cell/s]#015Executing:   4%|▍         | 9/201 [00:01<00:23,  8.14cell/s]#015Executing:   5%|▌         | 11/201 [00:01<00:20,  9.32cell/s]#015Executing:   6%|▋         | 13/201 [00:03<01:16,  2.45cell/s]#015Executing:   8%|▊         | 16/201 [00:04<00:48,  3.82cell/s]#015Executing:   9%|▉         | 19/201 [00:04<00:33,  5.39cell/s]#015Executing:  11%|█         | 22/201 [00:04<00:24,  7.32cell/s]#015Executing:  12%|█▏        | 25/201 [00:04<00:18,  9.42cell/s]#015Executing:  14%|█▍        | 28/201 [00:04<00:18,  9.29cell/s]#015Executing:  15%|█▌        | 31/201 [00:04<00:15, 11.16cell/s]#015Executing:  16%|█▋        | 33/201 [00:05<00:20,  8.18cell/s]#015Executing:  18%|█▊        | 36/201 [00:05<00:16,  9.92cell/s]#015Executing:  19%|█▉        | 39/201 [00:05<00:13, 11.81cell/s]#015Executing:  20%|██        | 41/201 [00:06<00:17,  9.27cell/s]#015Executing:  21%|██▏       | 43/201 [00:06<00:26,  5.98cell/s]#015Executing:  23%|██▎       | 46/201 [00:07<00:25,  6.08cell/s]#015Executing:  24%|██▍       | 48/201 [00:07<00:21,  7.21cell/s]#015Executing:  25%|██▌       | 51/201 [00:07<00:22,  6.79cell/s]#015Executing:  26%|██▋       | 53/201 [00:07<00:18,  7.96cell/s]#015Executing:  28%|██▊       | 56/201 [00:08<00:14, 10.01cell/s]#015Executing:  29%|██▉       | 59/201 [00:08<00:11, 11.90cell/s]#015Executing:  30%|███       | 61/201 [00:08<00:20,  6.96cell/s]#015Executing:  31%|███▏      | 63/201 [00:09<00:16,  8.18cell/s]#015Executing:  33%|███▎      | 66/201 [00:09<00:17,  7.60cell/s]#015Executing:  34%|███▍      | 68/201 [00:09<00:15,  8.75cell/s]#015Executing:  35%|███▍      | 70/201 [00:09<00:12, 10.28cell/s]#015Executing:  36%|███▌      | 72/201 [00:09<00:11, 11.72cell/s]#015Executing:  37%|███▋      | 74/201 [00:09<00:09, 13.19cell/s]#015Executing:  38%|███▊      | 76/201 [00:10<00:08, 14.19cell/s]#015Executing:  39%|███▉      | 78/201 [00:10<00:13,  9.04cell/s]#015Executing:  40%|███▉      | 80/201 [00:10<00:11, 10.52cell/s]#015Executing:  41%|████      | 82/201 [00:10<00:10, 11.58cell/s]#015Executing:  42%|████▏     | 84/201 [00:10<00:08, 13.17cell/s]#015Executing:  43%|████▎     | 86/201 [00:11<00:08, 12.97cell/s]#015Executing:  44%|████▍     | 88/201 [00:11<00:08, 14.01cell/s]#015Executing:  45%|████▍     | 90/201 [00:11<00:07, 14.85cell/s]#015Executing:  46%|████▌     | 92/201 [00:11<00:06, 15.78cell/s]#015Executing:  47%|████▋     | 94/201 [00:11<00:06, 16.17cell/s]#015Executing:  48%|████▊     | 96/201 [00:11<00:06, 16.43cell/s]#015Executing:  49%|████▉     | 98/201 [00:11<00:09, 10.56cell/s]#015Executing:  50%|████▉     | 100/201 [00:12<00:08, 11.92cell/s]#015Executing:  51%|█████     | 102/201 [00:12<00:07, 13.41cell/s]#015Executing:  52%|█████▏    | 104/201 [00:12<00:06, 14.33cell/s]#015Executing:  53%|█████▎    | 106/201 [00:12<00:13,  7.20cell/s]#015Executing:  54%|█████▎    | 108/201 [00:12<00:10,  8.69cell/s]#015Executing:  55%|█████▍    | 110/201 [00:13<00:09, 10.03cell/s]#015Executing:  56%|█████▌    | 112/201 [00:13<00:07, 11.18cell/s]#015Executing:  57%|█████▋    | 114/201 [00:13<00:07, 12.04cell/s]#015Executing:  58%|█████▊    | 116/201 [00:13<00:06, 12.71cell/s]#015Executing:  59%|█████▊    | 118/201 [00:13<00:06, 13.68cell/s]#015Executing:  60%|█████▉    | 120/201 [00:13<00:05, 14.25cell/s]#015Executing:  61%|██████    | 122/201 [00:14<00:08,  9.34cell/s]#015Executing:  62%|██████▏   | 124/201 [00:14<00:07, 10.67cell/s]#015Executing:  63%|██████▎   | 126/201 [00:14<00:06, 11.82cell/s]#015Executing:  64%|██████▎   | 128/201 [00:14<00:05, 12.76cell/s]#015Executing:  65%|██████▍   | 130/201 [00:14<00:07,  9.56cell/s]#015Executing:  66%|██████▌   | 132/201 [00:14<00:06, 11.09cell/s]#015Execu ...
# Uploaded to: s3://retail-mlops-edu-202602/output/titanic-competition-step-by-step-using-xgboost_output.ipynb
# 2026-02-10 15:48:21,955 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2026-02-10 15:48:39 Uploading - Uploading generated training model
# 2026-02-10 15:48:39 Completed - Training job completed
# Training seconds: 130
# Billable seconds: 130

# %%
# 이후, 최신 트레이닝 잡 정보 접근
training_job_name = estimator.latest_training_job.name
print("Training Job Name:", training_job_name)

# CloudWatch 로그 그룹과 스트림 이름 가져오기
log_group = f"/aws/sagemaker/TrainingJobs"
log_stream = f"{training_job_name}/algo-1"

print("Log Group:", log_group)
print("Log Stream:", log_stream)
# Out:
# Training Job Name: custom-training-2026-02-10-15-45-43-653
# Log Group: /aws/sagemaker/TrainingJobs
# Log Stream: custom-training-2026-02-10-15-45-43-653/algo-1

# %%
import boto3

logs_client = boto3.client("logs", region_name="us-east-1")

# %%
streams = logs_client.describe_log_streams(
    logGroupName="/aws/sagemaker/TrainingJobs",
    logStreamNamePrefix=f"{training_job_name}/algo-1"
)

for stream in streams['logStreams']:
    print(stream['logStreamName'])  # 전체 UUID 포함된 스트림 이름
# Out:
# custom-training-2026-02-10-15-45-43-653/algo-1-1770738388
