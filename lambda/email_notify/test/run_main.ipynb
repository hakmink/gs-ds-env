# %%
import sys

sys.path.append('/home/ec2-user/SageMaker/gs-ds-env/lambda/email_notify/src')

# %%
import main

# %%
context = {}
event = {
    'username': 'sean@gs.co.kr',
    'title': '람다에서의 이메일 테스트',
    'email_body': '메일 테스트',
}

# %%
main.lambda_handler(event, context)
# Out:
# {'email_body': '메일 테스트', 'title': '람다에서의 이메일 테스트', 'username': 'sean@gs.co.kr'}
# {'api_key': 'app-3Vhzd1RYHuijiVRMF2z15EMo', 'to': ['sean@gs.co.kr <sean@gs.co.kr>'], 'sender': 'GS Microwave 팀 <sean@52g.team>', 'subject': '람다에서의 이메일 테스트', 'text_body': '메일 테스트', 'custom_headers': [{'header': 'Reply-To', 'value': 'GS Microwave 팀 <sean@52g.team>'}]}
# {'request_id': '6b04b375-428c-4478-a1c1-16b56f8e46fd', 'data': {'error': "The 'api_key' parameter was not found in the request payload or in the 'X-Smtp2go-Api-Key' header or it wasn't in the correct format 'api-[A-Za-z0-9]{32}'; this is required for an API call to function. Please ammend your request to include your full 'api_key' and ensure that you include the Content-Type header, set to 'application/json'. The full key can be found in the API Keys section in the admin console - Code(01JM0WWHT96Y867DPGESCFZTA5)", 'error_code': 'E_ApiResponseCodes.INVALID_IN_PAYLOAD'}}
# 'succeeded'
# {'statusCode': 500,
# ...
