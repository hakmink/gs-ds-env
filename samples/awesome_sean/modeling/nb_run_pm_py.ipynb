# %%
conf_s3_path = "s3://gs-retail-awesome-conf-us-west-2/dev/sample/titanic-survival-prediction/baseline-sean-v1/"
notebook_path = "./titanic_modeling.ipynb"
work_dir = "./"

# %%
# !python run_pm.py   --conf-s3-path s3://gs-retail-awesome-conf-us-west-2/dev/sample/titanic-survival-prediction/baseline-awesome-sean-v1/   --notebook-path s3://gs-retail-awesome-conf-us-west-2/dev/sample/titanic-survival-prediction/baseline-awesome-sean-v1/modeling.ipynb
# Out:
# Traceback (most recent call last):
#   File "/home/ec2-user/SageMaker/gs-ds-env/tests/titanic/notebooks/sample_sean/run_pm_2/modeling/run_pm.py", line 12, in <module>
#     import papermill as pm
# ModuleNotFoundError: No module named 'papermill'

# %% [markdown]
# # run code
# ```
# python run_pm.py    \
# --conf-s3-path s3://gs-retail-awesome-conf-us-west-2/dev/sample/titanic-survival-prediction/baseline-awesome-sean-v1/   \
# --notebook-path s3://gs-retail-awesome-conf-us-west-2/dev/sample/titanic-survival-prediction/baseline-awesome-sean-v1/modeling.ipynb
# ```
